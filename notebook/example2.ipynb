# %%
url='https://github.com/Mritunjay1121/Datasets/raw/main/Data_Train.tar.gz'

# %%
import os
os.path.basename(url)
# Out:
# 'Data_Train.tar.gz'

# %%
import pandas as pd
import sys
os. getcwd()
# Out:
# 'c:\\Users\\mritu\\PycharmProjects\\Projects\\flight_fare_prediction\\notebook'

# %%
df=pd.read_csv('c:\\Users\\mritu\\PycharmProjects\\Projects\\flight_fare_prediction\\notebook\\new_train.csv')
df
# Out:
#        Total_Stops  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0                0   3897           24              3        22       20
# 1                2   7662            1              5         5       50
# 2                2  13882            9              6         9       25
# 3                1   6218           12              5        18        5
# 4                1  13302            1              3        16       50
# ...            ...    ...          ...            ...       ...      ...
# 10677            0   4107            9              4        19       55
# 10678            0   4145           27              4        20       45
# 10679            0   7229           27              4         8       20
# 10680            0  12648            1              3        11       30
# 10681            2  11753            9              5        10       55
#
#        Arrival_hour  Arrival_min  Duration_hours  Duration_mins  ...  \
# ...

# %%
df =  df.astype(float)
dd={}
for i in df.columns:
    dd[i]=df[i].dtype
dd
# Out:
# {'Total_Stops': dtype('float64'),
#  'Price': dtype('float64'),
#  'Journey_day': dtype('float64'),
#  'Journey_month': dtype('float64'),
#  'Dep_hour': dtype('float64'),
#  'Dep_min': dtype('float64'),
#  'Arrival_hour': dtype('float64'),
#  'Arrival_min': dtype('float64'),
#  'Duration_hours': dtype('float64'),
#  'Duration_mins': dtype('float64'),
#  'Airline_Air India': dtype('float64'),
#  'Airline_GoAir': dtype('float64'),
#  'Airline_IndiGo': dtype('float64'),
#  'Airline_Jet Airways': dtype('float64'),
#  'Airline_Jet Airways Business': dtype('float64'),
#  'Airline_Multiple carriers': dtype('float64'),
#  'Airline_Multiple carriers Premium economy': dtype('float64'),
#  'Airline_SpiceJet': dtype('float64'),
#  'Airline_Trujet': dtype('float64'),
#  'Airline_Vistara': dtype('float64'),
#  'Airline_Vistara Premium economy': dtype('float64'),
#  'Source_Chennai': dtype('float64'),
#  'Source_Delhi': dtype('float64'),
#  'Source_Kolkata': dtype('float64'),
# ...

# %%
df2=pd.read_csv("housing.csv")
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
